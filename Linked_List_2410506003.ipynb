# %%
# @title Latihan 1
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    def display(self):
        temp = self.head
        if not temp:
            print("Jadwal mata kuliah kosong!")
            return
        print("\nJadwal mata kuliah hari Jumat!")
        idx = 1
        while temp:
            print(f"{idx}. {temp.data}")
            temp = temp.next
            idx += 1

jadwal_jumat = LinkedList()

jumlah_matkul = 3
print(f"Masukkan jumlah matkul hari jumat: {jumlah_matkul}")

for i in range(1, jumlah_matkul + 1):
    matkul = input(f"Masukkan matkul ke-{i} : ")
    jadwal_jumat.append(matkul)

jadwal_jumat.display()
# Out:
# Masukkan jumlah matkul hari jumat: 3
# Masukkan matkul ke-1 : kalkulus lanjut
# Masukkan matkul ke-2 : praktikum struktur data
# Masukkan matkul ke-3 : aljabar linear
#
# Jadwal mata kuliah hari Jumat!
# 1. kalkulus lanjut
# 2. praktikum struktur data
# 3. aljabar linear

# %%
# @title Latihan 2
class Node:
    def __init__(self, folder_name):
        self.folder_name = folder_name
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.current = None

    def add_folder(self, folder_name):
        new_node = Node(folder_name)
        if self.head is None:
            self.head = self.tail = self.current = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def move_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"Anda berpindah ke: {self.current.folder_name}")
        else:
            print("Tidak bisa maju! Ini riwayat terakhir")

    def move_backward(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"Anda kembali ke: {self.current.folder_name}")
        else:
            print("Tidak bisa kembali! Ini riwayat pertama")

    def display_history(self):
        temp = self.head
        index = 1
        print("\nRiwayat folder:")
        while temp:
            print(f"{index}. {temp.folder_name}")
            temp = temp.next
            index += 1

jumlah_folder = int(input("Masukkan jumlah folder yang dikunjungi: "))
folder_history = DoublyLinkedList()

for i in range(jumlah_folder):
    folder_name = input(f"Masukkan folder ke {i+1}: ")
    folder_history.add_folder(folder_name)

folder_history.display_history()

while True:
    command = input("\nTekan B untuk kembali, Tekan F untuk maju, dan Tekan X untuk selesai: ").upper()
    if command == "F":
        folder_history.move_forward()
    elif command == "B":
        folder_history.move_backward()
    elif command == "X":
        break
    else:
        print("Perintah tidak dikenali!")
# Out:
# Masukkan jumlah folder yang dikunjungi: 3
# Masukkan folder ke 1: download
# Masukkan folder ke 2: document
# Masukkan folder ke 3: video
#
# Riwayat folder:
# 1. download
# 2. document
# 3. video
#
# Tekan B untuk kembali, Tekan F untuk maju, dan Tekan X untuk selesai: B
# Tidak bisa kembali! Ini riwayat pertama
#
# Tekan B untuk kembali, Tekan F untuk maju, dan Tekan X untuk selesai: F
# Anda berpindah ke: document
#
# Tekan B untuk kembali, Tekan F untuk maju, dan Tekan X untuk selesai: B
# Anda kembali ke: download
#
# Tekan B untuk kembali, Tekan F untuk maju, dan Tekan X untuk selesai: X

# %%
# @title Latihan 3
# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data  # Menyimpan nilai node
        self.next = None  # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None  # Awalnya, daftar kosong

    # Menambahkan elemen di awal
    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Menambahkan elemen di akhir
    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, position, data):
        if position < 0:
            print("Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print("Posisi melebihi panjang daftar!")
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    # Menghapus elemen di awal
    def delete_at_beginning(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        self.head = self.head.next

    # Menghapus elemen di akhir
    def delete_at_end(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print("Posisi tidak ditemukan!")
                return
            temp = temp.next
        if not temp.next:
            print("Posisi tidak ditemukan!")
            return
        temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                print(f"Elemen {key} ditemukan dalam daftar!")
                return
            temp = temp.next
        print(f"Elemen {key} tidak ditemukan dalam daftar.")

    # Membalik (reverse) Linked List
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Linked List
    def display(self):
        if not self.head:
            print("Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")


# ======= Program Utama (Main) ======= #

# Membuat objek Linked List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("Masukkan jumlah awal elemen dalam daftar: "))
for i in range(num_elements):
    data = int(input(f"Masukkan data ke-{i+1}: "))
    ll.add_at_end(data)

# Menu Operasi Linked List
while True:
    print("\nPilih Operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi tertentu")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data: "))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(position, data)
    elif choice == 4:
        ll.delete_at_beginning()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus: "))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int(input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print("Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\nKeluar dari program.")
        break
    else:
        print("\nPilihan tidak valid, silakan coba lagi!")

# %%
# @title Tugas Jadwal Satpam
class Node:
    def __init__(self, name):
        self.name = name
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def add_guard(self, name):
        new_node = Node(name)
        if not self.head:
            self.head = new_node
            self.head.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    def print_schedule(self, days=14):
        if not self.head:
            print("Jadwal tidak dapat dicetak, daftar satpam kosong!")
            return

        print("\n📌 Jadwal Piket Satpam Selama 2 Minggu:\n")
        temp = self.head
        for day in range(1, days + 1):
            print(f"Hari {day}: {temp.name}")
            temp = temp.next

# Program Utama
if __name__ == "__main__":
    cll = CircularLinkedList()

    for i in range(1, 5):
        name = input(f"Masukkan nama satpam ke-{i}: ")
        cll.add_guard(name)

    cll.print_schedule()
# Out:
# Masukkan nama satpam ke-1: Kartika Salsabila
# Masukkan nama satpam ke-2: Apfia Dian Setianingrum
# Masukkan nama satpam ke-3: David Nazal Farihin
# Masukkan nama satpam ke-4: Muhammad Yogi Istianto Wibowo
#
# 📌 Jadwal Piket Satpam Selama 2 Minggu:
#
# Hari 1: Kartika Salsabila
# Hari 2: Apfia Dian Setianingrum
# Hari 3: David Nazal Farihin
# Hari 4: Muhammad Yogi Istianto Wibowo
# Hari 5: Kartika Salsabila
# Hari 6: Apfia Dian Setianingrum
# Hari 7: David Nazal Farihin
# Hari 8: Muhammad Yogi Istianto Wibowo
# Hari 9: Kartika Salsabila
# Hari 10: Apfia Dian Setianingrum
# Hari 11: David Nazal Farihin
# Hari 12: Muhammad Yogi Istianto Wibowo
# Hari 13: Kartika Salsabila
# Hari 14: Apfia Dian Setianingrum
